# %% [markdown]
# Data analysis for the binary continuous likert experiment

# %% [markdown]
# First, import all the modules and libraries necessary

# %%
from zipfile import ZipFile
import json
from pathlib import Path
from matplotlib import pyplot as plt
import pandas as pd
import warnings 
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from matplotlib import pyplot as plt

# %% [markdown]
# Import data

# %%
zip_file_name = "bin-cont-likert-12-16-2025.zip"

indv_data_frames = []

with ZipFile(zip_file_name, 'r') as zip_file:
    for file_name in zip_file.namelist():
        if file_name.endswith('.csv'):
            df = pd.read_csv(zip_file.open(file_name))
            indv_data_frames.append(df)

# %% [markdown]
# Clean the data

# %%
combined_data_frame = pd.concat(indv_data_frames, ignore_index = True)

print(combined_data_frame)
# Out:
#                  trial_type  trial_index plugin_version  time_elapsed  \
# 0                  pavlovia            0            NaN          1317
# 1             external-html            1            NaN          4365
# 2              instructions            2            NaN          6102
# 3              instructions            3            NaN          6980
# 4                  pavlovia            0            NaN          1327
# ..                      ...          ...            ...           ...
# 757  html-keyboard-response            5          2.1.0         36143
# 758                pavlovia            0            NaN          2430
# 759            instructions            1            NaN          5359
# 760  html-keyboard-response            2          2.1.0          6495
# 761  html-keyboard-response            3          2.1.0          7098
#
#                            subject_id                          plot condition  \
# 0    gme91lqhsrowpuznxv9z6c9wdawc1h1k  binary_0.30230805510781_.png       [1]
# 1    gme91lqhsrowpuznxv9z6c9wdawc1h1k  binary_0.30230805510781_.png       [1]
# 2    gme91lqhsrowpuznxv9z6c9wdawc1h1k  binary_0.30230805510781_.png       [1]
# 3    gme91lqhsrowpuznxv9z6c9wdawc1h1k  binary_0.30230805510781_.png       [1]
# 4    72oct28ey2452z0txbk9awsdp511a8vj                           NaN       [1]
# ..                                ...                           ...       ...
# 757  3xcwh8hs15418u9kjpotsb0sj54bpscf                           NaN       [2]
# 758                               NaN                           NaN       [2]
# 759                               NaN                           NaN       [2]
# 760                               NaN                           NaN       [2]
# 761                               NaN                           NaN       [2]
#
#          rt           url                                       view_history  \
# 0       NaN           NaN                                                NaN
# 1    3040.0  consent.html                                                NaN
# 2    1736.0           NaN  [{"page_index":0,"viewing_time":1035},{"page_i...
# 3     877.0           NaN  [{"page_index":0,"viewing_time":441},{"page_in...
# 4       NaN           NaN                                                NaN
# ..      ...           ...                                                ...
# 757  1133.0           NaN                                                NaN
# 758     NaN           NaN                                                NaN
# 759  2926.0           NaN  [{"page_index":0,"viewing_time":1060},{"page_i...
# 760  1134.0           NaN                                                NaN
# 761   601.0           NaN                                                NaN
#
#                                               stimulus response  \
# 0                                                  NaN      NaN
# 1                                                  NaN      NaN
# 2                                                  NaN      NaN
# 3                                                  NaN      NaN
# 4                                                  NaN      NaN
# ..                                                 ...      ...
# 757                 Now the graph will be shown to you        a
# 758                                                NaN      NaN
# 759                                                NaN      NaN
# 760                 Now the graph will be shown to you        v
# 761  <div style='float: center;'><img src= conditio...        v
#
#     question_order success  study_id  session_id
# 0              NaN     NaN       NaN         NaN
# 1              NaN     NaN       NaN         NaN
# 2              NaN     NaN       NaN         NaN
# 3              NaN     NaN       NaN         NaN
# 4              NaN     NaN       NaN         NaN
# ..             ...     ...       ...         ...
# 757            NaN     NaN       NaN         NaN
# 758            NaN     NaN       NaN         NaN
# 759            NaN     NaN       NaN         NaN
# 760            NaN     NaN       NaN         NaN
# 761            NaN     NaN       NaN         NaN
#
# [762 rows x 16 columns]

# %% [markdown]
# Make data frame for only survey-likert trials

# %%
is_likert_mask = combined_data_frame['trial_type']=='survey-likert'   

likert_df = combined_data_frame[is_likert_mask]

print(likert_df)
# Out:
#         trial_type  trial_index plugin_version  time_elapsed  \
# 17   survey-likert            6            NaN         11922
# 26   survey-likert            6            NaN         11110
# 35   survey-likert            6            NaN         29598
# 44   survey-likert            6            NaN         14520
# 53   survey-likert            6            NaN         11243
# ..             ...          ...            ...           ...
# 708  survey-likert            6            NaN         13581
# 717  survey-likert            6            NaN         12113
# 726  survey-likert            6            NaN         10637
# 738  survey-likert            6            NaN         26441
# 750  survey-likert            7            NaN        350329
#
#                            subject_id                               plot  \
# 17   7vf8suazjq0q9kapzo416ql0qvr77n4n   continuous_0.43906666276199_.png
# 26   fzu0u9g4lmsb1r56ooh9131axx0of4l7      binary_0.616832475402624_.png
# 35   php7jbppld04td37qskxm3tfndnvarzn      binary_0.616832475402624_.png
# 44   lp1qau1d9r1lg9w0ehuy327tg7zay5jn       binary_0.30230805510781_.png
# 53   5alzuncws9dpqpmfh3t863x9rahgzrf5   continuous_0.43906666276199_.png
# ..                                ...                                ...
# 708  z4rhmwadjutsdoqu5c7dttdtzto58azk  continuous_0.616832475402624_.png
# 717  og65wu97pqa0lkq4yhawagjrtl783y3o       binary_0.43906666276199_.png
# 726  yg8jco4vs8sgqfqv51jd5o6wp9xsh224  continuous_0.616832475402624_.png
# 738  ccpyvto1l54hmar65ygjy7cw9vgbtqjj  continuous_0.616832475402624_.png
# 750  4w46ru5tblfeo09mamswm3bkps58vb1a                                NaN
#
#     condition       rt  url view_history stimulus  \
# 17        [2]   2760.0  NaN          NaN      NaN
# 26        [1]   2452.0  NaN          NaN      NaN
# 35        [1]   3650.0  NaN          NaN      NaN
# 44        [1]   3263.0  NaN          NaN      NaN
# 53        [2]   2390.0  NaN          NaN      NaN
# ..        ...      ...  ...          ...      ...
# 708       [2]   3644.0  NaN          NaN      NaN
# 717       [1]   2346.0  NaN          NaN      NaN
# 726       [2]   2487.0  NaN          NaN      NaN
# 738       [2]  16819.0  NaN          NaN      NaN
# 750       [2]   5992.0  NaN          NaN      NaN
#
#                                               response question_order success  \
# 17                          {"Amount":9,"Attention":9}          [0,1]     NaN
# 26                          {"Amount":7,"Attention":9}          [0,1]     NaN
# 35                          {"Attention":9,"Amount":7}          [1,0]     NaN
# 44                          {"Amount":6,"Attention":9}          [0,1]     NaN
# 53                          {"Amount":7,"Attention":9}          [0,1]     NaN
# ..                                                 ...            ...     ...
# 708                         {"Attention":9,"Amount":5}          [1,0]     NaN
# 717                         {"Attention":9,"Amount":4}          [1,0]     NaN
# 726                         {"Attention":9,"Amount":6}          [1,0]     NaN
# 738                         {"Attention":9,"Amount":0}          [1,0]     NaN
# 750  {"Amount":6,"Attention":7,"Affected":5,"Freque...      [0,3,2,1]     NaN
#
#      study_id  session_id
# 17        NaN         NaN
# 26        NaN         NaN
# 35        NaN         NaN
# 44        NaN         NaN
# 53        NaN         NaN
# ..        ...         ...
# 708       NaN         NaN
# 717       NaN         NaN
# 726       NaN         NaN
# 738       NaN         NaN
# 750       NaN         NaN
#
# [71 rows x 16 columns]

# %% [markdown]
# Drop columns

# %%
columns_to_drop = ['trial_index', 'plugin_version', 'url', 'view_history', 'stimulus', 'study_id' , 'session_id', 'success']

likert_df = likert_df.drop(columns_to_drop, axis = 1)

print(likert_df)
# Out:
#         trial_type  time_elapsed                        subject_id  \
# 17   survey-likert         11922  7vf8suazjq0q9kapzo416ql0qvr77n4n
# 26   survey-likert         11110  fzu0u9g4lmsb1r56ooh9131axx0of4l7
# 35   survey-likert         29598  php7jbppld04td37qskxm3tfndnvarzn
# 44   survey-likert         14520  lp1qau1d9r1lg9w0ehuy327tg7zay5jn
# 53   survey-likert         11243  5alzuncws9dpqpmfh3t863x9rahgzrf5
# ..             ...           ...                               ...
# 708  survey-likert         13581  z4rhmwadjutsdoqu5c7dttdtzto58azk
# 717  survey-likert         12113  og65wu97pqa0lkq4yhawagjrtl783y3o
# 726  survey-likert         10637  yg8jco4vs8sgqfqv51jd5o6wp9xsh224
# 738  survey-likert         26441  ccpyvto1l54hmar65ygjy7cw9vgbtqjj
# 750  survey-likert        350329  4w46ru5tblfeo09mamswm3bkps58vb1a
#
#                                   plot condition       rt  \
# 17    continuous_0.43906666276199_.png       [2]   2760.0
# 26       binary_0.616832475402624_.png       [1]   2452.0
# 35       binary_0.616832475402624_.png       [1]   3650.0
# 44        binary_0.30230805510781_.png       [1]   3263.0
# 53    continuous_0.43906666276199_.png       [2]   2390.0
# ..                                 ...       ...      ...
# 708  continuous_0.616832475402624_.png       [2]   3644.0
# 717       binary_0.43906666276199_.png       [1]   2346.0
# 726  continuous_0.616832475402624_.png       [2]   2487.0
# 738  continuous_0.616832475402624_.png       [2]  16819.0
# 750                                NaN       [2]   5992.0
#
#                                               response question_order
# 17                          {"Amount":9,"Attention":9}          [0,1]
# 26                          {"Amount":7,"Attention":9}          [0,1]
# 35                          {"Attention":9,"Amount":7}          [1,0]
# 44                          {"Amount":6,"Attention":9}          [0,1]
# 53                          {"Amount":7,"Attention":9}          [0,1]
# ..                                                 ...            ...
# 708                         {"Attention":9,"Amount":5}          [1,0]
# 717                         {"Attention":9,"Amount":4}          [1,0]
# 726                         {"Attention":9,"Amount":6}          [1,0]
# 738                         {"Attention":9,"Amount":0}          [1,0]
# 750  {"Amount":6,"Attention":7,"Affected":5,"Freque...      [0,3,2,1]
#
# [71 rows x 8 columns]

# %% [markdown]
# Drop rows with missing data for plot

# %%
likert_df = likert_df.dropna(subset=['plot'])
print(likert_df)
# Out:
#         trial_type  time_elapsed                        subject_id  \
# 17   survey-likert         11922  7vf8suazjq0q9kapzo416ql0qvr77n4n
# 26   survey-likert         11110  fzu0u9g4lmsb1r56ooh9131axx0of4l7
# 35   survey-likert         29598  php7jbppld04td37qskxm3tfndnvarzn
# 44   survey-likert         14520  lp1qau1d9r1lg9w0ehuy327tg7zay5jn
# 53   survey-likert         11243  5alzuncws9dpqpmfh3t863x9rahgzrf5
# 62   survey-likert         13793  w3r6m8tqzsps9x88l84j8qg36pwkq5rf
# 85   survey-likert         11980  dyu643r5gbwoo9lde9hshcx5e2nd4qeh
# 95   survey-likert         12852  70o1maay8o1tf2jzxlkez8hdwgduuvzf
# 118  survey-likert        136068  oxmt4j60e801a4v66psu747zdf2szsr4
# 127  survey-likert         10294  3xz6xj9jcpfvd2ggaq4dfqtjamd3ej08
# 155  survey-likert        330158  ktoyalq5gn8a4lyg38hfb72mqsf2h8ak
# 164  survey-likert         15264  onmxv7rzbj872356zmhqbu9rscd7etwj
# 176  survey-likert         14023  lvem6pk9n4xdrgb756h3toykap57qhog
# 200  survey-likert         13364  e1f7jqq25dypvj0j6f6otbuca4106h5n
# 209  survey-likert         13776  2fdllpncvnj48xc3xh39z4e091an80l5
# 218  survey-likert         11947  j70n00c01rcaf00lyuxypme93n6wg35h
# 227  survey-likert         13340  gehg70ro2q9wtf4567qg91fj5lss36hr
# 236  survey-likert         18512  xbqltkmhm7lhw2mpwjheh9xkxopga8cx
# 245  survey-likert         18892  aof6tds2e7osf7hxtn4j10jrn4q6mzzh
# 275  survey-likert         16099  z1oy8qec50hhf938tytfuyldo7q7p4gh
# 290  survey-likert         13169  0b92vxovdcdk5fahjvpl2v9w5x4ayhp4
# 301  survey-likert         13527  le2pvzqkj93ddr7xfuv9goopu2xryf5g
# 310  survey-likert         17522  tfj32uy1s4z4ne5fk2qx4ole9bm7y6zs
# 319  survey-likert        111439  m62ycfwl2utjdw1kt15e3x7zwv3q1u7y
# 337  survey-likert         15645  phvzavcdmdo066xdsj6rbhdh3svx0x7f
# 352  survey-likert          9604  g9dyylnex137ptjbsdjdjk3q7qp7ze76
# 369  survey-likert         14321  kgvdrpp10cqrkfygnlsmrsecl9jy7a4c
# 378  survey-likert         12284  e0lpc6zzgfnu39d02b799wvjzxrs0501
# 402  survey-likert         12487  82z97nfl7rgn8wfcyc27ppft1gh0skjg
# 433  survey-likert         17284  otoad8n8w2f4tn4l4zsx6rqq1nq06dvx
# 442  survey-likert         13691  wujp7uw6ku9rpv8evqu3wed680hxwdor
# 460  survey-likert         15091  eoqx33aqp69zu3q399n3g2vl5aozw5wb
# 469  survey-likert         19358  ct5mrkdeuaq9aerx3par9wg79811w79g
# 495  survey-likert         14824  k52nem0ewspwsah4vjaw77b8zp5w9jrj
# 519  survey-likert         20135  5pfdcbdper3ygqlbc2o4gcfs9zzqt9q6
# 614       binary_0.30230805510781_.png       [1]   3601.0
# 642  continuous_0.616832475402624_.png       [2]   3549.0
# 657   continuous_0.30230805510781_.png       [2]   2660.0
# 689       binary_0.30230805510781_.png       [1]   5035.0
# 708  continuous_0.616832475402624_.png       [2]   3644.0
# 717       binary_0.43906666276199_.png       [1]   2346.0
# 726  continuous_0.616832475402624_.png       [2]   2487.0
# 738  continuous_0.616832475402624_.png       [2]  16819.0
#
#                        response question_order
# 17   {"Amount":9,"Attention":9}          [0,1]
# 26   {"Amount":7,"Attention":9}          [0,1]
# 35   {"Attention":9,"Amount":7}          [1,0]
# 44   {"Amount":6,"Attention":9}          [0,1]
# 53   {"Amount":7,"Attention":9}          [0,1]
# 62   {"Amount":6,"Attention":9}          [0,1]
# 85   {"Amount":8,"Attention":9}          [0,1]
# 95   {"Attention":9,"Amount":4}          [1,0]
# 118  {"Amount":6,"Attention":9}          [0,1]
# 127  {"Amount":4,"Attention":9}          [0,1]
# 155  {"Attention":9,"Amount":5}          [1,0]
# 164  {"Attention":9,"Amount":1}          [1,0]
# 176  {"Attention":9,"Amount":5}          [1,0]
# 200  {"Attention":9,"Amount":4}          [1,0]
# 209  {"Attention":9,"Amount":5}          [1,0]
# 218  {"Amount":6,"Attention":9}          [0,1]
# 227  {"Attention":9,"Amount":1}          [1,0]
# 236  {"Attention":9,"Amount":3}          [1,0]
# 245  {"Attention":4,"Amount":7}          [1,0]
# 275  {"Amount":7,"Attention":9}          [0,1]
# 290  {"Amount":9,"Attention":9}          [0,1]
# 301  {"Amount":2,"Attention":9}          [0,1]
# 310  {"Amount":0,"Attention":0}          [0,1]
# 319  {"Amount":5,"Attention":9}          [0,1]
# 337  {"Amount":5,"Attention":9}          [0,1]
# 352  {"Attention":9,"Amount":5}          [1,0]
# 369  {"Amount":2,"Attention":9}          [0,1]
# 378  {"Amount":8,"Attention":9}          [0,1]
# 402  {"Amount":8,"Attention":9}          [0,1]
# 433  {"Attention":9,"Amount":1}          [1,0]
# 442  {"Amount":7,"Attention":4}          [0,1]
# 460  {"Attention":9,"Amount":4}          [1,0]
# 469  {"Attention":5,"Amount":2}          [1,0]
# 495  {"Attention":9,"Amount":4}          [1,0]
# 519  {"Attention":9,"Amount":4}          [1,0]
# 528  {"Attention":6,"Amount":4}          [1,0]
# 566  {"Amount":7,"Attention":9}          [0,1]
# 599  {"Amount":4,"Attention":9}          [0,1]
# 614  {"Attention":9,"Amount":2}          [1,0]
# 642  {"Attention":9,"Amount":4}          [1,0]
# 657  {"Amount":6,"Attention":9}          [0,1]
# 689  {"Attention":9,"Amount":3}          [1,0]
# 708  {"Attention":9,"Amount":5}          [1,0]
# 717  {"Attention":9,"Amount":4}          [1,0]
# 726  {"Attention":9,"Amount":6}          [1,0]
# 738  {"Attention":9,"Amount":0}          [1,0]

# %% [markdown]
# Add value for correlation level

# %%
likert_df['correlation'] = likert_df['plot'].str.split('_').str[1].str[:5]

# %% [markdown]
# Make the likert scale responses into columns

# %%
# 1. Unpack the 'response' dictionary/JSON column
# The .apply(pd.Series) method will automatically create new columns named 'Attention' and 'Amount'
response_columns = likert_df['response'].apply(lambda x: json.loads(x) if isinstance(x, str) else x).apply(pd.Series)

# 2. Concatenate the new columns with the main DataFrame
likert_df = pd.concat([likert_df.drop('response', axis=1), response_columns], axis=1)

# 3. Convert the new columns to a numeric type (they might be strings after extraction)
likert_df['Attention'] = pd.to_numeric(likert_df['Attention'], errors='coerce')
likert_df['Amount'] = pd.to_numeric(likert_df['Amount'], errors='coerce')

print(likert_df.shape[0])
print(likert_df)
# Out:
# 46
#         trial_type  time_elapsed                        subject_id  \
# 17   survey-likert         11922  7vf8suazjq0q9kapzo416ql0qvr77n4n
# 26   survey-likert         11110  fzu0u9g4lmsb1r56ooh9131axx0of4l7
# 35   survey-likert         29598  php7jbppld04td37qskxm3tfndnvarzn
# 44   survey-likert         14520  lp1qau1d9r1lg9w0ehuy327tg7zay5jn
# 53   survey-likert         11243  5alzuncws9dpqpmfh3t863x9rahgzrf5
# 62   survey-likert         13793  w3r6m8tqzsps9x88l84j8qg36pwkq5rf
# 85   survey-likert         11980  dyu643r5gbwoo9lde9hshcx5e2nd4qeh
# 95   survey-likert         12852  70o1maay8o1tf2jzxlkez8hdwgduuvzf
# 118  survey-likert        136068  oxmt4j60e801a4v66psu747zdf2szsr4
# 127  survey-likert         10294  3xz6xj9jcpfvd2ggaq4dfqtjamd3ej08
# 155  survey-likert        330158  ktoyalq5gn8a4lyg38hfb72mqsf2h8ak
# 164  survey-likert         15264  onmxv7rzbj872356zmhqbu9rscd7etwj
# 176  survey-likert         14023  lvem6pk9n4xdrgb756h3toykap57qhog
# 200  survey-likert         13364  e1f7jqq25dypvj0j6f6otbuca4106h5n
# 209  survey-likert         13776  2fdllpncvnj48xc3xh39z4e091an80l5
# 218  survey-likert         11947  j70n00c01rcaf00lyuxypme93n6wg35h
# 227  survey-likert         13340  gehg70ro2q9wtf4567qg91fj5lss36hr
# 236  survey-likert         18512  xbqltkmhm7lhw2mpwjheh9xkxopga8cx
# 245  survey-likert         18892  aof6tds2e7osf7hxtn4j10jrn4q6mzzh
# 275  survey-likert         16099  z1oy8qec50hhf938tytfuyldo7q7p4gh
# 290  survey-likert         13169  0b92vxovdcdk5fahjvpl2v9w5x4ayhp4
# 301  survey-likert         13527  le2pvzqkj93ddr7xfuv9goopu2xryf5g
# 310  survey-likert         17522  tfj32uy1s4z4ne5fk2qx4ole9bm7y6zs
# 319  survey-likert        111439  m62ycfwl2utjdw1kt15e3x7zwv3q1u7y
# 337  survey-likert         15645  phvzavcdmdo066xdsj6rbhdh3svx0x7f
# 352  survey-likert          9604  g9dyylnex137ptjbsdjdjk3q7qp7ze76
# 369  survey-likert         14321  kgvdrpp10cqrkfygnlsmrsecl9jy7a4c
# 378  survey-likert         12284  e0lpc6zzgfnu39d02b799wvjzxrs0501
# 319   continuous_0.43906666276199_.png       [2]   3159.0          [0,1]
# 337       binary_0.43906666276199_.png       [1]   3720.0          [0,1]
# 352  continuous_0.616832475402624_.png       [2]   2350.0          [1,0]
# 369  continuous_0.616832475402624_.png       [2]   3343.0          [0,1]
# 378      binary_0.616832475402624_.png       [1]   2830.0          [0,1]
# 402      binary_0.616832475402624_.png       [1]   3348.0          [0,1]
# 433       binary_0.30230805510781_.png       [1]   3641.0          [1,0]
# 442   continuous_0.30230805510781_.png       [2]   4667.0          [0,1]
# 460   continuous_0.30230805510781_.png       [2]   3836.0          [1,0]
# 469       binary_0.43906666276199_.png       [1]   8684.0          [1,0]
# 495       binary_0.43906666276199_.png       [1]   4023.0          [1,0]
# 519       binary_0.43906666276199_.png       [1]   7813.0          [1,0]
# 528       binary_0.30230805510781_.png       [1]   3515.0          [1,0]
# 566  continuous_0.616832475402624_.png       [2]   2719.0          [0,1]
# 599       binary_0.43906666276199_.png       [1]   4003.0          [0,1]
# 614       binary_0.30230805510781_.png       [1]   3601.0          [1,0]
# 642  continuous_0.616832475402624_.png       [2]   3549.0          [1,0]
# 657   continuous_0.30230805510781_.png       [2]   2660.0          [0,1]
# 689       binary_0.30230805510781_.png       [1]   5035.0          [1,0]
# 708  continuous_0.616832475402624_.png       [2]   3644.0          [1,0]
# 717       binary_0.43906666276199_.png       [1]   2346.0          [1,0]
# 726  continuous_0.616832475402624_.png       [2]   2487.0          [1,0]
# 738  continuous_0.616832475402624_.png       [2]  16819.0          [1,0]
#
#     correlation  Amount  Attention
# 17        0.439       9          9
# 26        0.616       7          9
# 35        0.616       7          9
# 44        0.302       6          9
# 53        0.439       7          9
# 62        0.439       6          9
# 85        0.439       8          9
# 95        0.302       4          9
# 118       0.302       6          9
# 127       0.302       4          9
# 155       0.302       5          9
# 164       0.302       1          9
# 176       0.439       5          9
# 200       0.302       4          9
# 209       0.439       5          9
# 218       0.439       6          9
# 227       0.439       1          9
# 236       0.616       3          9
# 245       0.302       7          4
# 275       0.302       7          9
# 290       0.616       9          9
# 301       0.302       2          9
# 310       0.439       0          0
# 319       0.439       5          9
# 337       0.439       5          9
# 352       0.616       5          9
# 369       0.616       2          9
# 378       0.616       8          9
# 402       0.616       8          9
# 433       0.302       1          9
# 442       0.302       7          4
# 460       0.302       4          9
# 469       0.439       2          5
# 495       0.439       4          9
# 519       0.439       4          9
# 528       0.302       4          6
# 566       0.616       7          9
# 599       0.439       4          9
# 614       0.302       2          9
# 642       0.616       4          9
# 657       0.302       6          9
# 689       0.302       3          9
# 708       0.616       5          9
# 717       0.439       4          9
# 726       0.616       6          9
# 738       0.616       0          9

# %% [markdown]
# Drop rows where "Attention" of response != 10. Pavlovia codes on a 0-index scale, so I'm dropping the values that are !=9

# %%
likert_df = likert_df[likert_df['Attention'] == 9].copy()

print(likert_df.shape[0])
print(likert_df.columns)
print(likert_df)
# Out:
# 41
# Index(['trial_type', 'time_elapsed', 'subject_id', 'plot', 'condition', 'rt',
#        'question_order', 'correlation', 'Amount', 'Attention'],
#       dtype='object')
#         trial_type  time_elapsed                        subject_id  \
# 17   survey-likert         11922  7vf8suazjq0q9kapzo416ql0qvr77n4n
# 26   survey-likert         11110  fzu0u9g4lmsb1r56ooh9131axx0of4l7
# 35   survey-likert         29598  php7jbppld04td37qskxm3tfndnvarzn
# 44   survey-likert         14520  lp1qau1d9r1lg9w0ehuy327tg7zay5jn
# 53   survey-likert         11243  5alzuncws9dpqpmfh3t863x9rahgzrf5
# 62   survey-likert         13793  w3r6m8tqzsps9x88l84j8qg36pwkq5rf
# 85   survey-likert         11980  dyu643r5gbwoo9lde9hshcx5e2nd4qeh
# 95   survey-likert         12852  70o1maay8o1tf2jzxlkez8hdwgduuvzf
# 118  survey-likert        136068  oxmt4j60e801a4v66psu747zdf2szsr4
# 127  survey-likert         10294  3xz6xj9jcpfvd2ggaq4dfqtjamd3ej08
# 155  survey-likert        330158  ktoyalq5gn8a4lyg38hfb72mqsf2h8ak
# 164  survey-likert         15264  onmxv7rzbj872356zmhqbu9rscd7etwj
# 176  survey-likert         14023  lvem6pk9n4xdrgb756h3toykap57qhog
# 200  survey-likert         13364  e1f7jqq25dypvj0j6f6otbuca4106h5n
# 209  survey-likert         13776  2fdllpncvnj48xc3xh39z4e091an80l5
# 218  survey-likert         11947  j70n00c01rcaf00lyuxypme93n6wg35h
# 227  survey-likert         13340  gehg70ro2q9wtf4567qg91fj5lss36hr
# 236  survey-likert         18512  xbqltkmhm7lhw2mpwjheh9xkxopga8cx
# 275  survey-likert         16099  z1oy8qec50hhf938tytfuyldo7q7p4gh
# 290  survey-likert         13169  0b92vxovdcdk5fahjvpl2v9w5x4ayhp4
# 301  survey-likert         13527  le2pvzqkj93ddr7xfuv9goopu2xryf5g
# 319  survey-likert        111439  m62ycfwl2utjdw1kt15e3x7zwv3q1u7y
# 337  survey-likert         15645  phvzavcdmdo066xdsj6rbhdh3svx0x7f
# 352  survey-likert          9604  g9dyylnex137ptjbsdjdjk3q7qp7ze76
# 369  survey-likert         14321  kgvdrpp10cqrkfygnlsmrsecl9jy7a4c
# 378  survey-likert         12284  e0lpc6zzgfnu39d02b799wvjzxrs0501
# 402  survey-likert         12487  82z97nfl7rgn8wfcyc27ppft1gh0skjg
# 433  survey-likert         17284  otoad8n8w2f4tn4l4zsx6rqq1nq06dvx
# 460  survey-likert         15091  eoqx33aqp69zu3q399n3g2vl5aozw5wb
# 495  survey-likert         14824  k52nem0ewspwsah4vjaw77b8zp5w9jrj
# 519  survey-likert         20135  5pfdcbdper3ygqlbc2o4gcfs9zzqt9q6
# 566  survey-likert         11436  trd20njbnzsmvoxumkw92dnl6530mk0e
# 599  survey-likert         13604  65w4p1jo0toa601uld53cuag4va6agzv
# 614  survey-likert         11609  xx6jzzltn6meh0dy29tv32e4dm31rpr4
# 642  survey-likert         11890  re4waw694bwpbm2kh8vf9yn6gek33496
# 708  continuous_0.616832475402624_.png       [2]   3644.0          [1,0]
# 717       binary_0.43906666276199_.png       [1]   2346.0          [1,0]
# 726  continuous_0.616832475402624_.png       [2]   2487.0          [1,0]
# 738  continuous_0.616832475402624_.png       [2]  16819.0          [1,0]
#
#     correlation  Amount  Attention
# 17        0.439       9          9
# 26        0.616       7          9
# 35        0.616       7          9
# 44        0.302       6          9
# 53        0.439       7          9
# 62        0.439       6          9
# 85        0.439       8          9
# 95        0.302       4          9
# 118       0.302       6          9
# 127       0.302       4          9
# 155       0.302       5          9
# 164       0.302       1          9
# 176       0.439       5          9
# 200       0.302       4          9
# 209       0.439       5          9
# 218       0.439       6          9
# 227       0.439       1          9
# 236       0.616       3          9
# 275       0.302       7          9
# 290       0.616       9          9
# 301       0.302       2          9
# 319       0.439       5          9
# 337       0.439       5          9
# 352       0.616       5          9
# 369       0.616       2          9
# 378       0.616       8          9
# 402       0.616       8          9
# 433       0.302       1          9
# 460       0.302       4          9
# 495       0.439       4          9
# 519       0.439       4          9
# 566       0.616       7          9
# 599       0.439       4          9
# 614       0.302       2          9
# 642       0.616       4          9
# 657       0.302       6          9
# 689       0.302       3          9
# 708       0.616       5          9
# 717       0.439       4          9
# 726       0.616       6          9
# 738       0.616       0          9

# %% [markdown]
# Make data frames for each of the 6 conditions
# ("binary_0.30230805510781_.png",
#         "binary_0.43906666276199_.png",
#         "binary_0.616832475402624_.png",
#         "continuous_0.30230805510781_.png",
#         "continuous_0.43906666276199_.png",
#         "continuous_0.616832475402624_.png")

# %%
#grouped_df = likert_df.groupby("plot")

# %%
#separate_dfs = {condition: plot for condition, plot in grouped_df}

# %%
#for value in separate_dfs:
    #print(separate_dfs[value])
    #print('*'*60)

# %% [markdown]
# Compute stats

# %% [markdown]
# Group by plot

# %%
# 1. Ensure Amount is numeric (in case it was imported as strings)
likert_df['Amount'] = pd.to_numeric(likert_df['Amount'])

# 2. Fit the One-Way ANOVA model 
# C(plot) treats the filenames as categorical levels
model_plot = ols('Amount ~ C(plot)', data=likert_df).fit()

# 3. Generate and print the ANOVA table
anova_table_plot = sm.stats.anova_lm(model_plot, typ=2)

print("One-Way ANOVA: Comparing Amount by Plot Type")
print(anova_table_plot)
# Out:
# One-Way ANOVA: Comparing Amount by Plot Type
#               sum_sq    df         F    PR(>F)
# C(plot)    56.464015   5.0  2.732295  0.034696
# Residual  144.657937  35.0       NaN       NaN

# %%
df_plot = likert_df

# 1. Check counts and variation for EVERY group
stats_check_plot = df_plot.groupby('plot')['Amount'].agg(['count', 'std', 'var'])
print("Group Stats Check:")
print(stats_check_plot)

# 2. Identify the 'problem' groups
zero_var = stats_check_plot[stats_check_plot['std'] == 0]
single_obs = stats_check_plot[stats_check_plot['count'] <= 1]

if not zero_var.empty:
    print("\nWarning: These groups have ZERO variance (all values are same):")
    print(zero_var.index.tolist())

if not single_obs.empty:
    print("\nWarning: These groups have only 1 observation:")
    print(single_obs.index.tolist())
# Out:
# Group Stats Check:
#                                    count       std       var
# plot
# binary_0.30230805510781_.png           7  1.889822  3.571429
# binary_0.43906666276199_.png          10  1.776388  3.155556
# binary_0.616832475402624_.png          4  0.577350  0.333333
# continuous_0.30230805510781_.png       7  2.115701  4.476190
# continuous_0.43906666276199_.png       4  1.707825  2.916667
# continuous_0.616832475402624_.png      9  2.697736  7.277778

# %% [markdown]
# Group by binary [1] vs cont [2]

# %%
# 2. Fit the One-Way ANOVA model 
# C(plot) treats the filenames as categorical levels
model_bin_cont = ols('Amount ~ C(condition)', data=likert_df).fit()

# 3. Generate and print the ANOVA table
anova_table_bin_cont = sm.stats.anova_lm(model_bin_cont, typ=2)

print("One-Way ANOVA: Comparing Amount by Plot Type")
print(anova_table_bin_cont)
# Out:
# One-Way ANOVA: Comparing Amount by Plot Type
#                   sum_sq    df         F    PR(>F)
# C(condition)    0.000523   1.0  0.000101  0.992019
# Residual      201.121429  39.0       NaN       NaN

# %%
df_bin_cont = likert_df

# 1. Check counts and variation for EVERY group
stats_check_bin_cont = df_bin_cont.groupby('condition')['Amount'].agg(['count', 'std', 'var'])
print("Group Stats Check:")
print(stats_check_bin_cont)

# 2. Identify the 'problem' groups
zero_var = stats_check_bin_cont[stats_check_bin_cont['std'] == 0]
single_obs = stats_check_bin_cont[stats_check_bin_cont['count'] <= 1]

if not zero_var.empty:
    print("\nWarning: These groups have ZERO variance (all values are same):")
    print(zero_var.index.tolist())

if not single_obs.empty:
    print("\nWarning: These groups have only 1 observation:")
    print(single_obs.index.tolist())
# Out:
# Group Stats Check:
#            count       std       var
# condition
# [1]           21  2.104417  4.428571
# [2]           20  2.433862  5.923684

# %% [markdown]
# Compare correlation levels

# %%
# 2. Fit the One-Way ANOVA model 
# C(plot) treats the filenames as categorical levels
model_correlation = ols('Amount ~ C(correlation)', data=likert_df).fit()

# 3. Generate and print the ANOVA table
anova_table_correlation = sm.stats.anova_lm(model_correlation, typ=2)

print("One-Way ANOVA: Comparing Amount by Plot Type")
print(anova_table_correlation)
# Out:
# One-Way ANOVA: Comparing Amount by Plot Type
#                     sum_sq    df         F    PR(>F)
# C(correlation)   18.605468   2.0  1.936833  0.158128
# Residual        182.516484  38.0       NaN       NaN

# %%
df_correlation = likert_df

# 1. Check counts and variation for EVERY group
stats_check_correlation = df_correlation.groupby('correlation')['Amount'].agg(['count', 'std', 'var'])
print("Group Stats Check:")
print(stats_check_correlation)

# 2. Identify the 'problem' groups
zero_var = stats_check_plot[stats_check_plot['std'] == 0]
single_obs = stats_check_plot[stats_check_plot['count'] <= 1]

if not zero_var.empty:
    print("\nWarning: These groups have ZERO variance (all values are same):")
    print(zero_var.index.tolist())

if not single_obs.empty:
    print("\nWarning: These groups have only 1 observation:")
    print(single_obs.index.tolist())
# Out:
# Group Stats Check:
#              count       std       var
# correlation
# 0.302           14  1.940035  3.763736
# 0.439           14  1.968153  3.873626
# 0.616           13  2.633609  6.935897
